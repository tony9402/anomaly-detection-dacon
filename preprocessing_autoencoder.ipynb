# %%
import warnings
warnings.filterwarnings('ignore')

from glob import glob
import pandas as pd
import numpy as np

from tqdm import tqdm
import os

from sklearn.preprocessing import LabelEncoder

import joblib

# %%
# Config
train_png_path    = "./data/train/*.png"
test_png_path     = "./data/test/*.png"
train_pandas_path = "./data/train_df.csv"

# %%
train_png = sorted(glob(train_png_path))
test_png = sorted(glob(test_png_path))
train_data = pd.read_csv(train_pandas_path)

# %%
train_data
# Out:
#       index  file_name       class state            label
# 0         0  10000.png  transistor  good  transistor-good
# 1         1  10001.png     capsule  good     capsule-good
# 2         2  10002.png  transistor  good  transistor-good
# 3         3  10003.png        wood  good        wood-good
# 4         4  10004.png      bottle  good      bottle-good
# ...     ...        ...         ...   ...              ...
# 4272   4272  14272.png  transistor  good  transistor-good
# 4273   4273  14273.png  transistor  good  transistor-good
# 4274   4274  14274.png        grid  good        grid-good
# 4275   4275  14275.png      zipper  good      zipper-good
# 4276   4276  14276.png       screw  good       screw-good
#
# [4277 rows x 5 columns]

# %%
file_names = train_data["file_name"]

# %%
def binarySearch(x):
    l, r = 0, len(file_names) - 1
    while l <= r:
        mid = (l + r) // 2
        if file_names[mid] == x:
            return True
        if x < file_names[mid]:
            r = mid - 1
        else:
            l = mid + 1
    return False

# %%
data_path = []
for path in train_png:
    ppath = os.path.abspath(path)
    filename = ppath.split('/')[-1]
    if binarySearch(filename):
        data_path.append(ppath)
    else:
        data_path.append('-')
        assert False

# %%
train_data['path'] = data_path

# %%
train_data
# Out:
#       index  file_name       class state            label  \
# 0         0  10000.png  transistor  good  transistor-good
# 1         1  10001.png     capsule  good     capsule-good
# 2         2  10002.png  transistor  good  transistor-good
# 3         3  10003.png        wood  good        wood-good
# 4         4  10004.png      bottle  good      bottle-good
# ...     ...        ...         ...   ...              ...
# 4272   4272  14272.png  transistor  good  transistor-good
# 4273   4273  14273.png  transistor  good  transistor-good
# 4274   4274  14274.png        grid  good        grid-good
# 4275   4275  14275.png      zipper  good      zipper-good
# 4276   4276  14276.png       screw  good       screw-good
#
#                                                    path
# 0     /dacon/dacon/anomaly-detection/data/train/1000...
# 1     /dacon/dacon/anomaly-detection/data/train/1000...
# 2     /dacon/dacon/anomaly-detection/data/train/1000...
# 3     /dacon/dacon/anomaly-detection/data/train/1000...
# 4     /dacon/dacon/anomaly-detection/data/train/1000...
# ...                                                 ...
# 4272  /dacon/dacon/anomaly-detection/data/train/1427...
# 4273  /dacon/dacon/anomaly-detection/data/train/1427...
# 4274  /dacon/dacon/anomaly-detection/data/train/1427...
# 4275  /dacon/dacon/anomaly-detection/data/train/1427...
# 4276  /dacon/dacon/anomaly-detection/data/train/1427...
#
# [4277 rows x 6 columns]

# %%
encoder = LabelEncoder()
train_data['encoded_label'] = encoder.fit_transform(train_data['label'])

# %%
with open('encoder.pickle', 'wb') as f:
    joblib.dump(encoder, f)

# %%
autoencoder_data = train_data.drop(train_data[train_data['state'] != 'good'].index)

# %%
train_data
# Out:
#       index  file_name       class state            label  \
# 0         0  10000.png  transistor  good  transistor-good
# 1         1  10001.png     capsule  good     capsule-good
# 2         2  10002.png  transistor  good  transistor-good
# 3         3  10003.png        wood  good        wood-good
# 4         4  10004.png      bottle  good      bottle-good
# ...     ...        ...         ...   ...              ...
# 4272   4272  14272.png  transistor  good  transistor-good
# 4273   4273  14273.png  transistor  good  transistor-good
# 4274   4274  14274.png        grid  good        grid-good
# 4275   4275  14275.png      zipper  good      zipper-good
# 4276   4276  14276.png       screw  good       screw-good
#
#                                                    path  encoded_label
# 0     /dacon/dacon/anomaly-detection/data/train/1000...             72
# 1     /dacon/dacon/anomaly-detection/data/train/1000...             15
# 2     /dacon/dacon/anomaly-detection/data/train/1000...             72
# 3     /dacon/dacon/anomaly-detection/data/train/1000...             76
# 4     /dacon/dacon/anomaly-detection/data/train/1000...              3
# ...                                                 ...            ...
# 4272  /dacon/dacon/anomaly-detection/data/train/1427...             72
# 4273  /dacon/dacon/anomaly-detection/data/train/1427...             72
# 4274  /dacon/dacon/anomaly-detection/data/train/1427...             28
# 4275  /dacon/dacon/anomaly-detection/data/train/1427...             84
# 4276  /dacon/dacon/anomaly-detection/data/train/1427...             55
#
# [4277 rows x 7 columns]

# %%
any(autoencoder_data['state'] != 'good')
# Out:
# False

# %%
autoencoder_data.to_csv('train_for_autoencoder.csv', index=None)
